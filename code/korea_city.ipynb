# %%
import folium
import pandas as pd
import os

dat=pd.read_csv("kr.csv")
dat
# Out:
#           city      lat       lng      country iso2 admin_name  capital  \
# 0        Seoul  37.5600  126.9900  South Korea   KR      Seoul  primary
# 1        Busan  35.1800  129.0750  South Korea   KR      Busan    admin
# 2      Incheon  37.4833  126.6333  South Korea   KR    Incheon    admin
# 3        Daegu  35.8717  128.6017  South Korea   KR      Daegu    admin
# 4      Gwangju  35.1653  126.8486  South Korea   KR    Gwangju    admin
# ..         ...      ...       ...          ...  ...        ...      ...
# 205     Sanseo  35.5836  127.3968  South Korea   KR    Jeonbuk    minor
# 206     Beonam  35.5324  127.5437  South Korea   KR    Jeonbuk    minor
# 207    Bangsan  38.2088  127.9503  South Korea   KR    Gangwon    minor
# 208  Dongmyeon  38.2013  128.0433  South Korea   KR    Gangwon    minor
# 209   Hwacheon  38.1071  127.7063  South Korea   KR    Gangwon    minor
#
#      population  population_proper
# 0    23016000.0         10013781.0
# ...
